# %%
import pandas as pd

# %%
data = pd.read_json("clients.json")
display(data)
# Out:
#      identifiant        name gender  age  number_of_children  is_married  \
# 0              0     Dominic      M   44                   1       False
# 1              1     Antonio      M   38                   3       False
# 2              2       Brody      M   76                   4        True
# 3              3      Cayden      M   65                   1        True
# 4              4  Alexandria      F   74                   2        True
# ..           ...         ...    ...  ...                 ...         ...
# 196          196       Henry      M   67                   4       False
# 197          197    Isabelle      F   75                   1        True
# 198          198      Sophia      F   79                   4        True
# 199          199       Nolan      M   86                   3        True
# 200          200     Abigail      F   74                   4       False
#
#      annual_income  annual_income_tax
# 0           353086             126173
# ...
