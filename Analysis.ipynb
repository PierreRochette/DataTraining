# %%
import pandas as pd

# %%
data = pd.read_json("clients.json")
display(data)
# Out:
#      identifiant      name gender  age  number_of_children  is_married
# 0              0     Brody      M   84                   0       False  \
# 1              1     Cesar      M   80                   4        True
# 2              2     Aiden      M   82                   4        True
# 3              3    Peyton      F   68                   3       False
# 4              4    Emmett      M   69                   0        True
# ..           ...       ...    ...  ...                 ...         ...
# 196          196  Dominick      M   68                   4       False
# 197          197     Ellie      F   94                   3        True
# 198          198    Jordan      M   42                   4       False
# 199          199      Noah      M   52                   4        True
# 200          200    Jordan      M   94                   3        True
#
#      annual_income  annual_income_tax
# 0           173393              56216
# ...
